# %%
# %run STDecoder.py
# Out:
# Using device: cuda:1
# 加载的 vocab 文件路径: STEncoder/gene_tokenizer_vocab_nolab.json
# Loaded 1015 spots
# Patch shape: (1015, 3, 32, 32)
# Token shape: (1015, 2048)
# Token dtype: object
# Using vocab_size from tokenizer: 19482
# Starting training...
# Starting training...
# ...
# Epoch 1/500: 100%|██████████| 254/254 [00:50<00:00,  5.00it/s, loss=9.02, accuracy=0.000, valid_tokens=6141]
# Epoch 1, Average Loss: 8.6654, Accuracy: 0.0005
# ...
# Epoch 2/500: 100%|██████████| 254/254 [00:50<00:00,  4.99it/s, loss=8.9, accuracy=0.001, valid_tokens=6141]
# Epoch 2, Average Loss: 8.5126, Accuracy: 0.0005
# ...
# Epoch 3/500: 100%|██████████| 254/254 [00:51<00:00,  4.92it/s, loss=8.92, accuracy=0.000, valid_tokens=6141]
# Epoch 3, Average Loss: 8.4844, Accuracy: 0.0005
# ...
# Epoch 4/500: 100%|██████████| 254/254 [00:51<00:00,  4.90it/s, loss=8.12, accuracy=0.001, valid_tokens=6141]
# Epoch 4, Average Loss: 8.4533, Accuracy: 0.0005
# ...
