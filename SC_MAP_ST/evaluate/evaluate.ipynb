# %%
# %run evaluate_benchmark_metrics.py \
    --composition_pred_csv /mnt/d/ST_Graduation_Project/SC_MAP_ST/deconv_results/STARmap/Spatial_cell_composition.csv \
    --composition_pred_csv2 /mnt/d/ST_Graduation_Project/SC_MAP_ST/evaluate/STARmap_tangram_composition.csv \
    --composition_true_csv /mnt/d/ST_Graduation_Project/SC_MAP_ST/evaluate/STARmap_density.csv \
    --method1_name MyMethod \
    --method2_name Tangram \
    --output_csv ./Excitatory_L4_metrics.csv
# Out:
# [Composition mode] Spots aligned: 189, Celltypes evaluated: 15
# MyMethod Mean PCC: 0.3516
# MyMethod Mean SSIM: 0.2876
# MyMethod Mean RMSE: 1.0892
# MyMethod Mean JS: 0.4204
# Per-celltype metrics saved to ./Excitatory_L4_metrics.csv
# Boxplot saved to ./Excitatory_L4_metrics_boxplot.png
# Tangram metrics saved to ./Excitatory_L4_metrics_method2.csv
# Boxplot saved to ./Excitatory_L4_metrics_method2_boxplot.png
# Multi-method boxplot saved to ./Excitatory_L4_metrics_multi_boxplot.png

# %%
# %run evaluate_benchmark_metrics.py \
    --composition_pred_csv /mnt/d/ST_Graduation_Project/SC_MAP_ST/deconv_results/STARmap/Spatial_cell_composition.csv \
    --composition_true_csv /mnt/d/ST_Graduation_Project/SC_MAP_ST/evaluate/STARmap/STARmap_density.csv \
    --celltype "Excitatory L4" \
    --output_csv ./Excitatory_L4_metrics.csv
# Out:
# [Composition mode] Spots aligned: 189, Celltypes evaluated: 1
# Method1 Mean PCC: 0.8652
# Method1 Mean SSIM: 0.7434
# Method1 Mean RMSE: 0.5192
# Method1 Mean JS: 0.1430
# Per-celltype metrics saved to ./Excitatory_L4_metrics.csv

# %%
# %run evaluate_single_celltype_pcc.py \
    --composition_pred_csv /mnt/d/ST_Graduation_Project/SC_MAP_ST/evaluate/STARmap_tangram_composition.csv \
    --composition_true_csv /mnt/d/ST_Graduation_Project/SC_MAP_ST/evaluate/STARmap_density.csv \
    --celltype "Excitatory L4" \
    --output_csv ./Excitatory_L4_metrics.csv

# %% [markdown]
# # my

# %%
# %run evaluate_benchmark_metrics.py \
    --composition_pred_csv /mnt/d/ST_Graduation_Project/SC_MAP_ST/deconv_results/DATA7//Spatial_cell_composition.csv \
    --composition_true_csv /mnt/d/ST_Graduation_Project/SC_MAP_ST/evaluate/Data7/density.csv \
    --output_csv ./DATA4_metrics.csv
# Out:
# [Composition mode] Spots aligned: 1000, Celltypes evaluated: 19
# Method1 Mean PCC: 0.7722
# Method1 Mean SSIM: 0.6984
# Method1 Mean RMSE: 0.6417
# Method1 Mean JS: 0.1768
# Per-celltype metrics saved to ./DATA4_metrics.csv

# %% [markdown]
# # RCTD

# %%
# %run evaluate_benchmark_metrics.py \
    --composition_pred_csv /mnt/d/ST_Graduation_Project/SC_MAP_ST/evaluate/Data7/RCTD_results.csv \
    --composition_true_csv /mnt/d/ST_Graduation_Project/SC_MAP_ST/evaluate/Data7/density.csv \
    --output_csv ./DATA7_metrics.csv
# Out:
# [Composition mode] Spots aligned: 1000, Celltypes evaluated: 19
# Method1 Mean PCC: 0.7783
# Method1 Mean SSIM: 0.6542
# Method1 Mean RMSE: 0.6321
# Method1 Mean JS: 0.1867
# Per-celltype metrics saved to ./DATA7_metrics.csv

# %% [markdown]
# # Trangram

# %%
# %run evaluate_benchmark_metrics.py \
    --composition_pred_csv /mnt/d/ST_Graduation_Project/SC_MAP_ST/evaluate/Data7/tangram_composition.csv \
    --composition_true_csv /mnt/d/ST_Graduation_Project/SC_MAP_ST/evaluate/Data7/dataset7_density.csv \
    --output_csv ./trangram_metrics.csv
# Out:
# [Composition mode] Spots aligned: 1000, Celltypes evaluated: 19
# Method1 Mean PCC: 0.6939
# Method1 Mean SSIM: 0.5578
# Method1 Mean RMSE: 0.7592
# Method1 Mean JS: 0.2500
# Per-celltype metrics saved to ./trangram_metrics.csv

# %% [markdown]
# # Spotlight

# %%
# %run evaluate_benchmark_metrics.py \
    --composition_pred_csv /mnt/d/ST_Graduation_Project/SC_MAP_ST/evaluate/Data24_SPOTlight_results.csv \
    --composition_true_csv /mnt/d/ST_Graduation_Project/SC_MAP_ST/evaluate/Data24_density.csv \
    --output_csv ./trangram_metrics.csv
# Out:
# [Composition mode] Spots aligned: 1000, Celltypes evaluated: 10
# Method1 Mean PCC: -0.0504
# Method1 Mean SSIM: -0.0231
# Method1 Mean RMSE: 1.4439
# Method1 Mean JS: 0.4316
# Per-celltype metrics saved to ./trangram_metrics.csv
# Boxplot saved to ./trangram_metrics_boxplot.png
# /mnt/d/ST_Graduation_Project/SC_MAP_ST/evaluate/evaluate_benchmark_metrics.py:144: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot(data, labels=metric_cols, showfliers=False)

# %% [markdown]
# # ALL

# %%
# %run evaluate_benchmark_metrics.py \
    --composition_true_csv /mnt/d/ST_Graduation_Project/SC_MAP_ST/evaluate/Data7/density.csv \
    --composition_pred_csv /mnt/d/ST_Graduation_Project/SC_MAP_ST/deconv_results/DATA7/Spatial_cell_composition.csv \
    --composition_pred_csv2 /mnt/d/ST_Graduation_Project/SC_MAP_ST/evaluate/Data7/tangram_composition.csv \
    --composition_pred_csv3 /mnt/d/ST_Graduation_Project/SC_MAP_ST/evaluate/Data7/RCTD_results.csv \
    --method1_name MyMethod \
    --method2_name Tangram \
    --method3_name RCTD \
    --output_csv ./DATA7_metrics.csv
# Out:
# [Composition mode] Spots aligned: 1000, Celltypes evaluated: 19
# MyMethod Mean PCC: 0.7567
# MyMethod Mean SSIM: 0.6622
# MyMethod Mean RMSE: 0.6741
# MyMethod Mean JS: 0.1923
# Per-celltype metrics saved to ./DATA7_metrics.csv
# Tangram metrics saved to ./DATA7_metrics_method2.csv
# RCTD metrics saved to ./DATA7_metrics_method3.csv
# Multi-method boxplot saved to ./DATA7_metrics_multi_boxplot.png

# %%
# %run evaluate_benchmark_metrics.py \
    --composition_true_csv /mnt/d/ST_Graduation_Project/SC_MAP_ST/evaluate/STARmap/STARmap_density.csv \
    --composition_pred_csv /mnt/d/ST_Graduation_Project/SC_MAP_ST/deconv_results/STARmap/Spatial_cell_composition.csv \
    --composition_pred_csv2 /mnt/d/ST_Graduation_Project/SC_MAP_ST/evaluate/STARmap/STARmap_tangram_composition.csv \
    --composition_pred_csv3 /mnt/d/ST_Graduation_Project/SC_MAP_ST/evaluate/STARmap/STARmap_RCTD_results.csv \
    --method1_name MyMethod \
    --method2_name Tangram \
    --method3_name RCTD \
    --output_csv ./STARmap_metrics.csv
# Out:
# [Composition mode] Spots aligned: 189, Celltypes evaluated: 15
# MyMethod Mean PCC: 0.5149
# MyMethod Mean SSIM: 0.4411
# MyMethod Mean RMSE: 0.9156
# MyMethod Mean JS: 0.3417
# Per-celltype metrics saved to ./STARmap_metrics.csv
# Tangram metrics saved to ./STARmap_metrics_method2.csv
# RCTD metrics saved to ./STARmap_metrics_method3.csv
# Multi-method boxplot saved to ./STARmap_metrics_multi_boxplot.png

# %%
# %run evaluate_benchmark_metrics.py \
  --reconstructed_csv /mnt/d/ST_Graduation_Project/SC_MAP_ST/deconv_results/GSE144236_P2/GSE144236_P2_reconstructed_all_genes.csv \
  --ground_truth_h5ad /mnt/d/ST_Graduation_Project_data/database/GSE144236/GSE144236_P2_ST.h5ad \
  --target_gene "EFNB1"
# Out:
# Target gene 'EFNB1' PCC: 0.816225

# %%
# %run evaluate_benchmark_metrics.py \
  --reconstructed_csv /mnt/d/ST_Graduation_Project/SC_MAP_ST/evaluate/GSE144236/trangram_expression.csv \
  --ground_truth_h5ad /mnt/d/ST_Graduation_Project_data/database/GSE144236/GSE144236_P2_ST.h5ad \
  --target_gene "EFNB1"
# Out:
# Target gene 'EFNB1' PCC: 0.809699

# %%
# %run gene_heatmap.py \
  --pred_csv /mnt/d/ST_Graduation_Project/SC_MAP_ST/deconv_results/GSE144236_P2/GSE144236_P2_reconstructed_all_genes.csv \
  --ground_truth_h5ad /mnt/d/ST_Graduation_Project_data/database/GSE144236/GSE144236_P2_ST.h5ad \
  --target_gene EFNB1 \
  --log1p \
  --output_png EFNB1_heatmap.png
# Out:
# GT: mean=0.6328, median=0.6931, min=0.0000, max=3.0445
# Pred: mean=1.2410, median=0.7217, min=0.0408, max=3.6252
# Saved heatmaps to EFNB1_heatmap.png
