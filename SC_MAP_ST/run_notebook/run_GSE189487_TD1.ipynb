# %% [markdown]
# python SC_MAP_ST/stage1.py \
#     --sc_file "/home/maweicheng/ST_data/GSE189487/GSE189487_SC.h5ad" \
#     --st_file "/home/maweicheng/ST_data/GSE189487/GSE189487_TD1_ST.h5ad" \
#     --n_epochs 300 \
#     --resolution 2 \
#     --loss_type zinb \
#     --beta 0.1 \
#     --lambda_mmd 1.0 \
#     --top_n_per_type 100 \
#     --latent_dim 256 \
#     --output_dir SC_MAP_ST/deconv_results/GSE189487_TD1
#  #   --precomputed_marker_file "../deconv_results/GSE189487_TD1/final_genes.txt"

# %%
# %run ../stage1.py \
    --sc_file "/mnt/d/ST_Graduation_Project_data/database/GSE189487/GSE189487_SC.h5ad" \
    --st_file "/mnt/d/ST_Graduation_Project_data/database/GSE189487/GSE189487_TD1_ST.h5ad" \
    --n_epochs 300 \
    --resolution 2 \
    --loss_type zinb \
    --beta 0.1 \
    --lambda_mmd 1.0 \
    --top_n_per_type 100 \
    --latent_dim 256 \
    --output_dir ../deconv_results/GSE189487_TD1
 #   --precomputed_marker_file "../deconv_results/GSE189487_TD1/final_genes.txt"

# %% [markdown]
# python SC_MAP_ST/stage2.py \
#     --st_file "/home/maweicheng/ST_data/GSE189487/GSE189487_TD1_ST.h5ad" \
#     --stage1_model_path "SC_MAP_ST/deconv_results/GSE189487_TD1/final_vae.pth" \
#     --output_dir "SC_MAP_ST/deconv_results/GSE189487_TD1/" \
#     --gat_hidden_dim 512 \
#     --gat_layers 4 \
#     --lr 1e-4 \
#     --loss_lambda_mse 0.05 \
#     --loss_lambda_cosine 2 \
#     --loss_lambda_pearson 2 \
#     --loss_lambda_reg 0.1 \
#     --loss_lambda_sparse 0.01 \
#     --loss_lambda_proportion 0.1 \
#     --k_spatial 10 \
#     --k_celltype 20 \
#     --batch_size 512 \
#     --n_epochs 500 \
#     --weight_threshold 0.05

# %%
# %run ../stage2.py \
    --st_file "/mnt/d/ST_Graduation_Project_data/database/GSE189487/GSE189487_TD1_ST.h5ad" \
    --stage1_model_path "../deconv_results/GSE189487_TD1/final_vae.pth" \
    --output_dir "../deconv_results/GSE189487_TD1/" \
    --gat_hidden_dim 512 \
    --gat_layers 4 \
    --lr 1e-4 \
    --loss_lambda_mse 0.05 \
    --loss_lambda_cosine 2 \
    --loss_lambda_pearson 2 \
    --loss_lambda_reg 0.1 \
    --loss_lambda_sparse 0.01 \
    --loss_lambda_proportion 0.1 \
    --k_spatial 10 \
    --k_celltype 20 \
    --batch_size 512 \
    --n_epochs 500 \
    --weight_threshold 0.05
