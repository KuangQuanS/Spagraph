# %%
# %run ../evaluate_benchmark_metrics.py \
    --reconstructed_csv /mnt/d/ST_Graduation_Project/SC_MAP_ST/deconv_results/CID44971/CID44971_reconstructed_all_genes.csv \
    --ground_truth_h5ad /mnt/d/ST_Graduation_Project_data/database/Wu/CID44971/CID44971_ST.h5ad \
    --output_csv ./CID44971_metrics.csv \
    --gene_list /mnt/d/ST_Graduation_Project/SC_MAP_ST/deconv_results/CID44971/final_genes.txt
# Out:
# Using top 1000 HVGs.
# Spots aligned: 1147, Genes evaluated: 1000
# Mean PCC: 0.0872
# Mean SSIM: 0.0823
# Mean RMSE: 1.3359
# Mean JS: 0.4667
# Per-gene metrics saved to ./CID44971_metrics.csv

# %%
# %run ../evaluate_benchmark_metrics.py \
    --reconstructed_csv /mnt/d/ST_Graduation_Project/SC_MAP_ST/evaluate/predicted_spatial_expression.csv \
    --ground_truth_h5ad /mnt/d/ST_Graduation_Project_data/database/Wu/CID44971/CID44971_ST.h5ad \
    --output_csv ./CID44971_metrics.csv \
    --gene_list /mnt/d/ST_Graduation_Project/SC_MAP_ST/deconv_results/CID44971/final_genes.txt
# Out:
# Using top 1000 HVGs.
# Spots aligned: 1147, Genes evaluated: 1000
# Mean PCC: 0.0762
# Mean SSIM: 0.0581
# Mean RMSE: 1.3553
# Mean JS: 0.4614
# Per-gene metrics saved to ./CID44971_metrics.csv

# %%
# %run ../evaluate_benchmark_metrics.py \
    --composition_pred_csv /mnt/d/ST_Graduation_Project/SC_MAP_ST/deconv_results/DATA24/Spatial_cell_composition.csv \
    --composition_true_csv /mnt/d/ST_Graduation_Project/SC_MAP_ST/evaluate/cell_type_density.csv \
    --output_csv ./CID44971_metrics.csv
# Out:
# [Composition mode] Spots aligned: 1000, Celltypes evaluated: 10
# Mean PCC: 0.6805
# Mean SSIM: 0.6508
# Mean RMSE: 0.7670
# Mean JS: 0.2110
# Per-celltype metrics saved to ./CID44971_metrics.csv
# Boxplot saved to ./CID44971_metrics_boxplot.png
# /mnt/d/ST_Graduation_Project/SC_MAP_ST/evaluate_benchmark_metrics.py:144: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot(data, labels=metric_cols, showfliers=False)

# %%
# %run ../evaluate_benchmark_metrics.py \
    --composition_pred_csv /mnt/d/ST_Graduation_Project/SC_MAP_ST/evaluate/tangram_cell_composition.csv \
    --composition_true_csv /mnt/d/ST_Graduation_Project/SC_MAP_ST/evaluate/cell_type_density.csv \
    --output_csv ./trangram_metrics.csv
# Out:
# [Composition mode] Spots aligned: 1000, Celltypes evaluated: 10
# Mean PCC: 0.7292
# Mean SSIM: 0.6113
# Mean RMSE: 0.7197
# Mean JS: 0.1786
# Per-celltype metrics saved to ./trangram_metrics.csv
# /mnt/d/ST_Graduation_Project/SC_MAP_ST/evaluate_benchmark_metrics.py:144: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot(data, labels=metric_cols, showfliers=False)
# Boxplot saved to ./trangram_metrics_boxplot.png
