# %%
# %run fusion_embedding_clustering.py --resolution 0.2 --n_neighbors 10 --point_size 100
# Out:
# === Fusion Embedding Leiden Clustering ===
# Mode: Center nodes only
#
# 1. Loading fusion embeddings...
# Loading NPZ file: /home/maweicheng/ST_Graduation_Project/evaluation_results/detailed_evaluation_results.npz
# Batch 0: center spot GSE203612_GSM6177601_AAACAAGTATCTCCCA-1, coord [1248.9845   581.07416]
# Sample 0: 11 spots, embedding shape: (11, 384)
# Batch 1: center spot GSE203612_GSM6177601_AAACCCGAACGAAATC-1, coord [1143.6738   424.85333]
# Sample 1: 11 spots, embedding shape: (11, 384)
# Batch 2: center spot GSE203612_GSM6177601_AAAGCTTGCCTACATA-1, coord [745.1783 341.8685]
# Sample 2: 11 spots, embedding shape: (11, 384)
# Total: 1015 spots, embedding shape: (1015, 384)
# Coordinate shape: (1015, 2)
# Coordinate range: X[329.3, 1354.6], Y[279.9, 1439.1]
#
# 2. Creating AnnData object...
# Created AnnData object: 1015 spots × 384 features
#
# 3. Performing Leiden clustering...
# Performing Leiden clustering with resolution=0.2, n_neighbors=10
# Found 6 clusters
# ...
