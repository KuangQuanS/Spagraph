# %%
# %run visualize.py \
    --max_edges 1000 \
    --csv_path evaluation_results/GSM6177601/edge_attention_analysis_filtered_attention>5.0_with_LR.csv \
    --image_path STimage-1K4M/breast/image/GSE203612_GSM6177601.png \
    --output_dir evaluation_results/GSM6177601/ \
    --spot_size 50 \
    --edge_width 2.0 \
    --specific_lr "CXCL12_CXCR4"
# Out:
# === CSV-based Spatial Transcriptomics Visualization ===
#
# 🎯 Creating specific LR visualization for: ['CXCL12_CXCR4']
# Found 3 edges for LR pairs: ['CXCL12_CXCR4']
# Specific LR visualization saved to: evaluation_results/GSM6177601/specific_lr_CXCL12_CXCR4.png
# Visualization complete!
