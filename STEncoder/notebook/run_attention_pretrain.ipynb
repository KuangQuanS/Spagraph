# %%
# !accelerate launch --multi_gpu ../attention_pretrain.py \
    --data_dir /home/maweicheng/ST_Graduation_Project/database/GSM6177601 \
    --output_dir /home/maweicheng/ST_Graduation_Project/STEncoder/checkpoints/GSM6177601/BERT \
    --vocab_file /home/maweicheng/ST_Graduation_Project/STEncoder/gene_tokenizer_vocab_nolab.json \
    --batch_size 16 \
    --bert_epochs 500 \
    --max_position_embeddings 2048 \
    --bert_lr 1e-4 \
    --model_type bert
# Out:
# ipex flag is deprecated, will be removed in Accelerate v1.10. From 2.7.0, PyTorch has all needed optimizations for Intel CPU and XPU.
# 2025-09-04 10:51:43 - INFO - Loading data...
# 2025-09-04 10:51:43 - INFO - Loading data...
# 2025-09-04 10:51:47 - INFO - Loaded 1015 token sequences and 1015 patches
# 2025-09-04 10:51:47 - INFO - Loaded 1015 token sequences and 1015 patches
# 加载的 vocab 文件路径: /home/maweicheng/ST_Graduation_Project/STEncoder/gene_tokenizer_vocab_nolab.json
# 2025-09-04 10:51:47 - INFO - Preparing BERT MLM training...
# 加载的 vocab 文件路径: /home/maweicheng/ST_Graduation_Project/STEncoder/gene_tokenizer_vocab_nolab.json
# 2025-09-04 10:51:47 - INFO - Preparing BERT MLM training...
# 2025-09-04 10:51:47 - INFO - Starting BERT MLM training...
# 2025-09-04 10:51:48 - INFO - PyTorch version 2.5.1 available.
# 2025-09-04 10:51:48 - INFO - PyTorch version 2.5.1 available.
# Epoch 1/500: 100%|███████████████████| 64/64 [00:06<00:00,  9.45it/s, loss=9.33]
# ...

# %%
# !accelerate launch --multi_gpu ../attention_pretrain.py \
    --data_dir /home/maweicheng/ST_Graduation_Project/database/GSM6177601 \
    --output_dir /home/maweicheng/ST_Graduation_Project/STEncoder/checkpoints/GSM6177601/VIT \
    --vocab_file /home/maweicheng/ST_Graduation_Project/STEncoder/gene_tokenizer_vocab_nolab.json \
    --batch_size 8 \
    --vit_epochs 500 \
    --vit_lr 3e-5 \
    --model_type vit
# Out:
# ipex flag is deprecated, will be removed in Accelerate v1.10. From 2.7.0, PyTorch has all needed optimizations for Intel CPU and XPU.
# 2025-09-04 13:41:53 - INFO - Loading data...
# 2025-09-04 13:41:53 - INFO - Loading data...
# 2025-09-04 13:41:56 - INFO - Loaded 1015 token sequences and 1015 patches
# 加载的 vocab 文件路径: /home/maweicheng/ST_Graduation_Project/STEncoder/gene_tokenizer_vocab_nolab.json
# 2025-09-04 13:41:57 - INFO - Preparing ViT MIM training...
# 2025-09-04 13:41:57 - INFO - Loaded 1015 token sequences and 1015 patches
# 2025-09-04 13:41:57 - INFO - 🚀 Starting ViT MIM training...
# 加载的 vocab 文件路径: /home/maweicheng/ST_Graduation_Project/STEncoder/gene_tokenizer_vocab_nolab.json
# 2025-09-04 13:41:57 - INFO - Preparing ViT MIM training...
# 2025-09-04 13:41:57 - INFO - PyTorch version 2.5.1 available.
# 2025-09-04 13:41:57 - INFO - PyTorch version 2.5.1 available.
# Epoch 1/500: 100%|██████████████████| 64/64 [00:06<00:00, 10.17it/s, loss=0.156]
# ...
