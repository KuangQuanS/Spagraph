# %% [markdown]
# # STARmap

# %%
# %run evaluate_benchmark_metrics.py \
    --composition_true_csv ./STARmap/Seurat.csv \
    --composition_pred_csv ./STARmap/RCTD.csv \
    --celltype "Excitatory L4" \
    --output_csv ./temp/temp.csv
# Out:
# [Info] All 15 cell types matched successfully.
# [Info] Method1 is already normalized.
# [Composition mode] Spots aligned: 189, Celltypes evaluated: 1
# Method1 Mean PCC: 0.8874
# Method1 Mean SSIM: 0.7555
# Method1 Mean RMSE: 0.4746
# Method1 Mean JS: 0.1619
# Per-celltype metrics saved to ./temp/temp.csv

# %%
# %run evaluate_benchmark_metrics.py \
    --composition_true_csv ./STARmap/STARmap_density.csv \
    --composition_pred_csv ./STARmap/STARmap_SP_cell_composition_k20.csv \
    --composition_pred_csv2 ./STARmap/STARmap_SP_cell_composition_k25.csv \
    --composition_pred_csv3 ./STARmap/STARmap_SP_cell_composition_k30.csv \
    --composition_pred_csv4 ./STARmap/STARmap_SP_cell_composition_k35.csv \
    --composition_pred_csv5 ./STARmap/STARmap_SP_cell_composition_k40.csv \
    --method1_name 20 \
    --method2_name 25 \
    --method3_name 30 \
    --method4_name 35 \
    --method5_name 40 \
    --use_union  \
    --output_csv ./temp/temp.csv
# Out:
# [Info] Using 15 total cell types (union mode, missing filled with zeros).
# [Info] 20 is already normalized.
# [Info] 25 is already normalized.
# [Info] 30 is already normalized.
# [Info] 35 is already normalized.
# [Info] 40 is already normalized.
# [Composition mode] Spots aligned: 189, Celltypes evaluated: 15
# Multi-method boxplot saved to ./temp/temp_multi_boxplot.png
#
# ...
# Average Ranking Score (ARS) - Based on PCC, SSIM, RMSE, JS
# ...
#
# 20:
#   Mean PCC: 0.4022 (Rank: 4.0)
#   Mean SSIM: 0.3449 (Rank: 4.0)
#   Mean RMSE: 1.0521 (Rank: 4.0)
#   Mean JS: 0.3776 (Rank: 4.0)
#   >>> ARS: 0.8000 (Higher is better) <<<
#
# 25:
#   Mean PCC: 0.4132 (Rank: 5.0)
#   Mean SSIM: 0.3452 (Rank: 5.0)
#   Mean RMSE: 1.0463 (Rank: 5.0)
#   Mean JS: 0.3746 (Rank: 5.0)
#   >>> ARS: 1.0000 (Higher is better) <<<
#
# 30:
#   Mean PCC: 0.3942 (Rank: 3.0)
#   Mean SSIM: 0.3265 (Rank: 3.0)
#   Mean RMSE: 1.0602 (Rank: 3.0)
#   Mean JS: 0.3782 (Rank: 3.0)
#   >>> ARS: 0.6000 (Higher is better) <<<
#
# ...

# %%
# %run evaluate_benchmark_metrics.py \
    --composition_true_csv ./STARmap/STARmap_density.csv \
    --composition_pred_csv ./STARmap/Spatial_cell_composition_0.88.csv \
    --composition_pred_csv2 ./STARmap/STARmap_tangram.csv \
    --composition_pred_csv3 ./STARmap/RCTD.csv \
    --composition_pred_csv4 ./STARmap/Seurat.csv \
    --composition_pred_csv5 ./STARmap/SpatialDWLS_result.csv \
    --composition_pred_csv6 ./STARmap/SPOTlight.csv \
    --composition_pred_csv7 ./STARmap/DestVI.csv \
    --composition_pred_csv8 ./STARmap/Stereoscope.csv \
    --method1_name Spagraph \
    --method2_name Tangram \
    --method3_name RCTD \
    --method4_name Seurat \
    --method5_name SpatialDWLS \
    --method6_name SPOTlight \
    --method7_name DestVI \
    --method8_name Stereoscope \
    --use_union \
    --output_csv ./STARmap/metrics.csv
# Out:
# [Info] Using 15 total cell types (union mode, missing filled with zeros).
# [Info] Spagraph is already normalized.
# [Info] Tangram is already normalized.
# [Info] RCTD is already normalized.
# [Info] Seurat is already normalized.
# [Info] SpatialDWLS is already normalized.
# [Info] SPOTlight is already normalized.
# [Info] DestVI is already normalized.
# [Info] Stereoscope is already normalized.
# [Composition mode] Spots aligned: 189, Celltypes evaluated: 15
# Multi-method boxplot saved to ./STARmap/metrics_multi_boxplot.png
#
# ...
# Average Ranking Score (ARS) - Based on PCC, SSIM, RMSE, JS
# ...
#
# Spagraph:
#   Mean PCC: 0.4878 (Rank: 4.0)
#   Mean SSIM: 0.4300 (Rank: 6.0)
#   Mean RMSE: 0.9395 (Rank: 5.0)
#   Mean JS: 0.3304 (Rank: 6.0)
#   >>> ARS: 0.6562 (Higher is better) <<<
#
# Tangram:
#   Mean PCC: 0.4834 (Rank: 3.0)
#   Mean SSIM: 0.3286 (Rank: 3.0)
#   Mean RMSE: 0.9525 (Rank: 3.0)
#   Mean JS: 0.3581 (Rank: 3.0)
#   >>> ARS: 0.3750 (Higher is better) <<<
#
# RCTD:
# ...

# %% [markdown]
# # my

# %%
for datanumber in range(1,33):
# datanumber=f"4"

    # %run evaluate_benchmark_metrics.py \
        --composition_true_csv ./Data{datanumber}/dataset{datanumber}_density.csv \
        --composition_pred_csv ./Data{datanumber}/Spatial_cell_composition.csv \
        --composition_pred_csv2 ./Data{datanumber}/tangram.csv \
        --composition_pred_csv3 ./Data{datanumber}/RCTD_results.csv \
        --composition_pred_csv4 ./Data{datanumber}/Seurat.csv \
        --composition_pred_csv5 ./Data{datanumber}/SpatialDWLS_result.csv \
        --composition_pred_csv6 ./Data{datanumber}/SPOTlight.csv \
        --composition_pred_csv7 ./Data{datanumber}/DestVI.csv \
        --composition_pred_csv8 ./Data{datanumber}/Stereoscope.csv \
        --method1_name Spagraph \
        --method2_name Tangram \
        --method3_name RCTD \
        --method4_name Seurat \
        --method5_name SpatialDWLS \
        --method6_name SPOTlight \
        --method7_name DestVI \
        --method8_name Stereoscope \
        --use_union \
        --output_csv ./Data{datanumber}/metrics.csv

#    --use_intersection \
# Out:
# [Info] Using 128 total cell types (union mode, missing filled with zeros).
# [Info] Spagraph is already normalized.
# [Info] Tangram is already normalized.
# [Info] RCTD is already normalized.
# [Info] Seurat is already normalized.
# [Info] SpatialDWLS is already normalized.
# [Info] SPOTlight is already normalized.
# [Info] DestVI is already normalized.
# [Info] Stereoscope is already normalized.
# [Composition mode] Spots aligned: 1000, Celltypes evaluated: 128
# pcc horizontal boxplot saved to ./Data1/metrics_pcc_boxplot.png
# ssim horizontal boxplot saved to ./Data1/metrics_ssim_boxplot.png
# rmse horizontal boxplot saved to ./Data1/metrics_rmse_boxplot.png
# js horizontal boxplot saved to ./Data1/metrics_js_boxplot.png
#
# ...
# Average Ranking Score (ARS) - Based on PCC, SSIM, RMSE, JS
# ...
#
# Spagraph:
#   Mean PCC: 0.5878 (Rank: 6.0)
#   Mean SSIM: 0.2921 (Rank: 3.0)
#   Mean RMSE: 0.9540 (Rank: 5.0)
#   Mean JS: 0.3364 (Rank: 6.0)
#   >>> ARS: 0.6250 (Higher is better) <<<
#
# ...

# %% [markdown]
# # 下面是看基因相似度的

# %% [markdown]
# # seqFish+

# %%
# %run evaluate_benchmark_metrics.py \
  --reconstructed_csv "F:\ST_Graduation_Project\spagraph_data\evaluate\seqFISH+\Dataset4_ST_reconstructed_all_genes.csv" \
  --ground_truth_h5ad "F:\ST_Graduation_Project\spagraph_data\evaluate\seqFISH+\Spatial.h5ad" \
  --target_gene "Igsf21,Rprm" \
  --output_pdf ./seqFISH+/gene_prediction_fig/

# %run evaluate_benchmark_metrics.py \
  --reconstructed_csv "F:\ST_Graduation_Project\spagraph_data\evaluate\seqFISH+\tangram_seqFISH+\trangram_expression.csv" \
  --ground_truth_h5ad "F:\ST_Graduation_Project\spagraph_data\evaluate\seqFISH+\Spatial.h5ad" \
  --target_gene "Igsf21,Rprm" \
  --output_pdf ./seqFISH+/tangram_gene_prediction_fig/

# %run evaluate_benchmark_metrics.py \
  --reconstructed_csv "F:\ST_Graduation_Project\spagraph_data\evaluate\seqFISH+\seurat_Igsf21_Rprm.csv" \
  --ground_truth_h5ad "F:\ST_Graduation_Project\spagraph_data\evaluate\seqFISH+\Spatial.h5ad" \
  --target_gene "Igsf21,Rprm" \
  --output_pdf ./seqFISH+/seurat_gene_prediction_fig/
# Out:
# Target gene 'Igsf21' PCC: 0.780396
# GT total sequencing depth (sum over 524 spots and 1 genes): 1478.000
# Pred total sequencing depth (sum over aligned spots/genes): 1024.689
# GT per-spot mean/median: 2.821/1.000
# Pred per-spot mean/median: 1.956/0.942
# GT: mean=2.8206, median=1.0000, min=0.0000, max=26.0000
# Pred: mean=1.9555, median=0.9419, min=0.0006, max=12.1912
# Saved Ground truth heatmap to ./seqFISH+/gene_prediction_fig/Igsf21_heatmap_GT.pdf
# Saved Prediction heatmap to ./seqFISH+/gene_prediction_fig/Igsf21_heatmap_Pred.pdf
# Target gene 'Rprm' PCC: 0.786865
# GT total sequencing depth (sum over 524 spots and 1 genes): 1434.000
# Pred total sequencing depth (sum over aligned spots/genes): 1001.198
# GT per-spot mean/median: 2.737/1.000
# Pred per-spot mean/median: 1.911/0.350
# GT: mean=2.7366, median=1.0000, min=0.0000, max=42.0000
# Pred: mean=1.9107, median=0.3498, min=0.0000, max=13.8168
# ...

# %% [markdown]
# # GSE144236

# %%
# %run evaluate_benchmark_metrics.py \
  --reconstructed_csv "f:/ST_Graduation_Project/spagraph_data/evaluate/GSE144236/Spatial_reconstructed.csv" \
  --ground_truth_h5ad "f:/ST_Graduation_Project/spagraph_data/database/GSE144240/GSE144236_P2_ST.h5ad" \
  --target_gene "PGF,NRP1,NRP2" \
  --output_pdf ./GSE144236/gene_prediction_fig/

# %run evaluate_benchmark_metrics.py \
  --reconstructed_csv "F:\ST_Graduation_Project\spagraph_data\evaluate\GSE144236\trangram_expression.csv" \
  --ground_truth_h5ad "f:/ST_Graduation_Project/spagraph_data/database/GSE144240/GSE144236_P2_ST.h5ad" \
  --target_gene "PGF,NRP1,NRP2" \
  --output_pdf ./GSE144236/gene_prediction_fig_tangram/
# Out:
# Target gene 'PGF' PCC: 0.643261
# GT total sequencing depth (sum over 646 spots and 1 genes): 445.000
# Pred total sequencing depth (sum over aligned spots/genes): 2398.454
# GT per-spot mean/median: 0.689/0.000
# Pred per-spot mean/median: 3.713/1.509
# GT: mean=0.6889, median=0.0000, min=0.0000, max=7.0000
# Pred: mean=3.7128, median=1.5088, min=0.0154, max=15.7451
# Saved Ground truth heatmap to ./GSE144236/gene_prediction_fig/PGF_heatmap_GT.pdf
# Saved Prediction heatmap to ./GSE144236/gene_prediction_fig/PGF_heatmap_Pred.pdf
# Target gene 'NRP1' PCC: 0.562395
# GT total sequencing depth (sum over 646 spots and 1 genes): 310.000
# Pred total sequencing depth (sum over aligned spots/genes): 2291.189
# GT per-spot mean/median: 0.480/0.000
# Pred per-spot mean/median: 3.547/2.335
# GT: mean=0.4799, median=0.0000, min=0.0000, max=6.0000
# Pred: mean=3.5467, median=2.3348, min=0.0126, max=25.4570
# Saved Ground truth heatmap to ./GSE144236/gene_prediction_fig/NRP1_heatmap_GT.pdf
# ...

# %% [markdown]
# ### GSE243275

# %%
# %run evaluate_benchmark_metrics.py \
  --reconstructed_csv "F:\ST_Graduation_Project\spagraph_data\evaluate\GSE243275\GSM7782699_ST_reconstructed.csv" \
  --ground_truth_h5ad f:/ST_Graduation_Project/spagraph_data/database/GSE243275/GSM7782699_ST.h5ad \
  --target_gene "ANGPTL4, PDGFRB, PDGFD, SDC1" \
  --heatmap_log1p \
  --output_pdf ./GSE243275/gene_prediction_fig/
# Out:
# e:\python\Lib\site-packages\anndata\_core\anndata.py:1758: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# Target gene 'ANGPTL4' PCC: 0.425658
# GT total sequencing depth (sum over 4992 spots and 1 genes): 3600.000
# Pred total sequencing depth (sum over aligned spots/genes): 3345.599
# GT per-spot mean/median: 0.721/0.000
# Pred per-spot mean/median: 0.670/0.517
# e:\python\Lib\site-packages\anndata\_core\anndata.py:1758: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# GT: mean=0.4021, median=0.0000, min=0.0000, max=2.5649
# Pred: mean=0.4663, median=0.4168, min=0.0000, max=1.9452
# Saved Ground truth heatmap to ./GSE243275/gene_prediction_fig/ANGPTL4_heatmap_GT.pdf
# Saved Prediction heatmap to ./GSE243275/gene_prediction_fig/ANGPTL4_heatmap_Pred.pdf
# Target gene 'PDGFRB' PCC: 0.756007
# ...

# %% [markdown]
# ### CID44971

# %%
# %run evaluate_benchmark_metrics.py \
  --reconstructed_csv ./CID44971/CID44971_ST_reconstructed.csv \
  --ground_truth_h5ad f:/ST_Graduation_Project/spagraph_data/database/Wu/CID44971/CID44971_ST.h5ad \
  --target_gene "CCL19,CCR7,ANGPTL4,SDC2"  \
  --output_pdf ./CID44971/gene_prediction_fig/
# Out:
# Target gene 'CCL19' PCC: 0.304856
# GT total sequencing depth (sum over 1147 spots and 1 genes): 1819.000
# Pred total sequencing depth (sum over aligned spots/genes): 4310.268
# GT per-spot mean/median: 1.586/0.000
# Pred per-spot mean/median: 3.758/0.412
# GT: mean=1.5859, median=0.0000, min=0.0000, max=92.0000
# Pred: mean=3.7579, median=0.4121, min=0.0000, max=62.7367
# Saved Ground truth heatmap to ./CID44971/gene_prediction_fig/CCL19_heatmap_GT.pdf
# Saved Prediction heatmap to ./CID44971/gene_prediction_fig/CCL19_heatmap_Pred.pdf
# Target gene 'CCR7' PCC: 0.557617
# GT total sequencing depth (sum over 1147 spots and 1 genes): 282.000
# Pred total sequencing depth (sum over aligned spots/genes): 2127.312
# GT per-spot mean/median: 0.246/0.000
# Pred per-spot mean/median: 1.855/1.037
# GT: mean=0.2459, median=0.0000, min=0.0000, max=6.0000
# Pred: mean=1.8547, median=1.0368, min=0.0163, max=18.9277
# ...
