# %%
# %run evaluate_benchmark_metrics.py \
    --composition_pred_csv /mnt/d/ST_Graduation_Project/SC_MAP_ST/deconv_results/STARmap/Spatial_cell_composition.csv \
    --composition_pred_csv2 /mnt/d/ST_Graduation_Project/SC_MAP_ST/evaluate/STARmap_tangram_composition.csv \
    --composition_true_csv /mnt/d/ST_Graduation_Project/SC_MAP_ST/evaluate/STARmap_density.csv \
    --method1_name MyMethod \
    --method2_name Tangram \
    --output_csv ./Excitatory_L4_metrics.csv
# Out:
# [Composition mode] Spots aligned: 189, Celltypes evaluated: 15
# MyMethod Mean PCC: 0.3516
# MyMethod Mean SSIM: 0.2876
# MyMethod Mean RMSE: 1.0892
# MyMethod Mean JS: 0.4204
# Per-celltype metrics saved to ./Excitatory_L4_metrics.csv
# Boxplot saved to ./Excitatory_L4_metrics_boxplot.png
# Tangram metrics saved to ./Excitatory_L4_metrics_method2.csv
# Boxplot saved to ./Excitatory_L4_metrics_method2_boxplot.png
# Multi-method boxplot saved to ./Excitatory_L4_metrics_multi_boxplot.png

# %%
# %run evaluate_benchmark_metrics.py \
    --composition_pred_csv /mnt/d/ST_Graduation_Project/SC_MAP_ST/deconv_results/STARmap/Spatial_cell_composition.csv \
    --composition_true_csv /mnt/d/ST_Graduation_Project/SC_MAP_ST/evaluate/STARmap/STARmap_density.csv \
    --celltype "Excitatory L4" \
    --output_csv ./Excitatory_L4_metrics.csv
# Out:
# [Composition mode] Spots aligned: 189, Celltypes evaluated: 1
# Method1 Mean PCC: 0.8652
# Method1 Mean SSIM: 0.7434
# Method1 Mean RMSE: 0.5192
# Method1 Mean JS: 0.1430
# Per-celltype metrics saved to ./Excitatory_L4_metrics.csv

# %%
# %run evaluate_single_celltype_pcc.py \
    --composition_pred_csv /mnt/d/ST_Graduation_Project/SC_MAP_ST/evaluate/STARmap_tangram_composition.csv \
    --composition_true_csv /mnt/d/ST_Graduation_Project/SC_MAP_ST/evaluate/STARmap_density.csv \
    --celltype "Excitatory L4" \
    --output_csv ./Excitatory_L4_metrics.csv
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File ~/miniconda3/envs/dl/lib/python3.10/site-packages/IPython/core/magics/execution.py:720, in ExecutionMagics.run(self, parameter_s, runner, file_finder)
#     719     fpath = arg_lst[0]
# --> 720     filename = file_finder(fpath)
#     721 except IndexError as e:
#
# File ~/miniconda3/envs/dl/lib/python3.10/site-packages/IPython/utils/path.py:91, in get_py_filename(name)
#      90         return py_name
# ---> 91 raise IOError("File `%r` not found." % name)
#
# OSError: File `'evaluate_single_celltype_pcc.py'` not found.
#
# The above exception was the direct cause of the following exception:
#
# Exception                                 Traceback (most recent call last)
# Cell In[38], line 1
# ...

# %%
# %run evaluate_benchmark_metrics.py \
    --reconstructed_csv /mnt/d/ST_Graduation_Project/SC_MAP_ST/deconv_results/CID44971/CID44971_reconstructed_all_genes.csv \
    --ground_truth_h5ad /mnt/d/ST_Graduation_Project_data/database/Wu/CID44971/CID44971_ST.h5ad \
    --output_csv ./CID44971_metrics.csv \
    --gene_list /mnt/d/ST_Graduation_Project/SC_MAP_ST/deconv_results/CID44971/final_genes.txt

# %%
# %run evaluate_benchmark_metrics.py \
    --reconstructed_csv /mnt/d/ST_Graduation_Project/SC_MAP_ST/evaluate/predicted_spatial_expression.csv \
    --ground_truth_h5ad /mnt/d/ST_Graduation_Project_data/database/Wu/CID44971/CID44971_ST.h5ad \
    --output_csv ./CID44971_metrics.csv \
    --gene_list /mnt/d/ST_Graduation_Project/SC_MAP_ST/deconv_results/CID44971/final_genes.txt

# %% [markdown]
# # my

# %%
# %run evaluate_benchmark_metrics.py \
    --composition_pred_csv /mnt/d/ST_Graduation_Project/SC_MAP_ST/deconv_results/STARmap/Spatial_cell_composition.csv \
    --composition_true_csv /mnt/d/ST_Graduation_Project/SC_MAP_ST/evaluate/STARmap/STARmap_density.csv \
    --output_csv ./STARmap_metrics.csv
# Out:
# [Composition mode] Spots aligned: 189, Celltypes evaluated: 15
# Method1 Mean PCC: 0.5149
# Method1 Mean SSIM: 0.4411
# Method1 Mean RMSE: 0.9156
# Method1 Mean JS: 0.3417
# Per-celltype metrics saved to ./STARmap_metrics.csv

# %% [markdown]
# # RCTD

# %%
# %run evaluate_benchmark_metrics.py \
    --composition_pred_csv /mnt/d/ST_Graduation_Project/SC_MAP_ST/evaluate/DATA24_RCTD_results.csv \
    --composition_true_csv /mnt/d/ST_Graduation_Project/SC_MAP_ST/evaluate/DATA24_density.csv \
    --output_csv ./DATA24_metrics.csv
# Out:
# [Composition mode] Spots aligned: 1000, Celltypes evaluated: 10
# Method1 Mean PCC: 0.8064
# Method1 Mean SSIM: 0.6767
# Method1 Mean RMSE: 0.6171
# Method1 Mean JS: 0.1218
# Per-celltype metrics saved to ./DATA24_metrics.csv
# Boxplot saved to ./DATA24_metrics_boxplot.png

# %% [markdown]
# # Trangram

# %%
# %run evaluate_benchmark_metrics.py \
    --composition_pred_csv /mnt/d/ST_Graduation_Project/SC_MAP_ST/evaluate/STARmap_tangram_composition.csv \
    --composition_true_csv /mnt/d/ST_Graduation_Project/SC_MAP_ST/evaluate/STARmap_density.csv \
    --output_csv ./trangram_metrics.csv
# Out:
# [Composition mode] Spots aligned: 189, Celltypes evaluated: 15
# Method1 Mean PCC: 0.4837
# Method1 Mean SSIM: 0.3287
# Method1 Mean RMSE: 0.9525
# Method1 Mean JS: 0.3583
# Per-celltype metrics saved to ./trangram_metrics.csv
# Boxplot saved to ./trangram_metrics_boxplot.png

# %% [markdown]
# # Spotlight

# %%
# %run evaluate_benchmark_metrics.py \
    --composition_pred_csv /mnt/d/ST_Graduation_Project/SC_MAP_ST/evaluate/Data24_SPOTlight_results.csv \
    --composition_true_csv /mnt/d/ST_Graduation_Project/SC_MAP_ST/evaluate/Data24_density.csv \
    --output_csv ./trangram_metrics.csv
# Out:
# [Composition mode] Spots aligned: 1000, Celltypes evaluated: 10
# Method1 Mean PCC: -0.0504
# Method1 Mean SSIM: -0.0231
# Method1 Mean RMSE: 1.4439
# Method1 Mean JS: 0.4316
# Per-celltype metrics saved to ./trangram_metrics.csv
# Boxplot saved to ./trangram_metrics_boxplot.png
# /mnt/d/ST_Graduation_Project/SC_MAP_ST/evaluate/evaluate_benchmark_metrics.py:144: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   ax.boxplot(data, labels=metric_cols, showfliers=False)

# %% [markdown]
# # ALL

# %%
# %run evaluate_benchmark_metrics.py \
    --composition_true_csv /mnt/d/ST_Graduation_Project/SC_MAP_ST/evaluate/Data24/Data24_density.csv \
    --composition_pred_csv /mnt/d/ST_Graduation_Project/SC_MAP_ST/deconv_results/DATA24/Spatial_cell_composition.csv \
    --composition_pred_csv2 /mnt/d/ST_Graduation_Project/SC_MAP_ST/evaluate/Data24/Data24_tangram_composition.csv \
    --composition_pred_csv3 /mnt/d/ST_Graduation_Project/SC_MAP_ST/evaluate/Data24/Data24_RCTD_results.csv \
    --method1_name MyMethod \
    --method2_name Tangram \
    --method3_name RCTD \
    --output_csv ./D24_metrics.csv
# Out:
# [Composition mode] Spots aligned: 1000, Celltypes evaluated: 10
# MyMethod Mean PCC: 0.8325
# MyMethod Mean SSIM: 0.7858
# MyMethod Mean RMSE: 0.5594
# MyMethod Mean JS: 0.1049
# Per-celltype metrics saved to ./D24_metrics.csv
# Tangram metrics saved to ./D24_metrics_method2.csv
# RCTD metrics saved to ./D24_metrics_method3.csv
# Multi-method boxplot saved to ./D24_metrics_multi_boxplot.png

# %%
# %run evaluate_benchmark_metrics.py \
    --composition_true_csv /mnt/d/ST_Graduation_Project/SC_MAP_ST/evaluate/STARmap/STARmap_density.csv \
    --composition_pred_csv /mnt/d/ST_Graduation_Project/SC_MAP_ST/deconv_results/STARmap/Spatial_cell_composition.csv \
    --composition_pred_csv2 /mnt/d/ST_Graduation_Project/SC_MAP_ST/evaluate/STARmap/STARmap_tangram_composition.csv \
    --method1_name MyMethod \
    --method2_name Tangram \
    --output_csv ./STARmap_metrics.csv
# Out:
# [Composition mode] Spots aligned: 189, Celltypes evaluated: 15
# MyMethod Mean PCC: 0.4717
# MyMethod Mean SSIM: 0.4241
# MyMethod Mean RMSE: 0.9726
# MyMethod Mean JS: 0.3667
# Per-celltype metrics saved to ./STARmap_metrics.csv
# Tangram metrics saved to ./STARmap_metrics_method2.csv
# Multi-method boxplot saved to ./STARmap_metrics_multi_boxplot.png
