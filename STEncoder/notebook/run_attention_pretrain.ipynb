# %%
# !accelerate launch --multi_gpu ../attention_pretrain.py \
    --data_dir /home/maweicheng/ST_COMM/breast_data \
    --output_dir STEncoder/checkpoints/attention_pretrain/breast/nolab/20250725_0908 \
    --vocab_file /home/maweicheng/ST_COMM/STEncoder/gene_tokenizer_vocab_nolab.json \
    --batch_size 16 \
    --bert_epochs 100 \
    --max_position_embeddings 2048 \
    --bert_lr 5e-5 \
    --model_type bert
# Out:
# ipex flag is deprecated, will be removed in Accelerate v1.10. From 2.7.0, PyTorch has all needed optimizations for Intel CPU and XPU.
# 2025-07-25 09:10:50 - INFO - Loading data...
# 2025-07-25 09:10:50 - INFO - Loading data...
# 2025-07-25 09:11:30 - INFO - Loaded 140219 token sequences and 140219 patches
# 加载的 vocab 文件路径: /home/maweicheng/ST_COMM/STEncoder/gene_tokenizer_vocab_nolab.json
# 2025-07-25 09:11:30 - INFO - Preparing BERT MLM training...
# 2025-07-25 09:11:30 - INFO - Loaded 140219 token sequences and 140219 patches
# 加载的 vocab 文件路径: /home/maweicheng/ST_COMM/STEncoder/gene_tokenizer_vocab_nolab.json
# 2025-07-25 09:11:30 - INFO - Preparing BERT MLM training...
# 2025-07-25 09:11:31 - INFO - PyTorch version 2.5.1 available.
# 2025-07-25 09:11:31 - INFO - PyTorch version 2.5.1 available.
# 2025-07-25 09:11:31 - INFO - Starting BERT MLM training...
# 2025-07-25 09:11:31 - INFO - Starting BERT MLM training...
# ...

# %%
# %run ../attention_pretrain.py \
    --data_dir /home/maweicheng/ST_COMM/npzdata \
    --output_dir ../checkpoints/attention_pretrain/20250718_1000 \
    --vocab_file /home/maweicheng/ST_COMM/STEncoder/gene_tokenizer_vocab.json \
    --batch_size 8 \
    --bert_epochs 500 \
    --max_position_embeddings 2048 \
    --bert_lr 5e-5 \
    --model_type bert
