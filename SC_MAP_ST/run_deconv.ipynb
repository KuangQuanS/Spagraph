# %%
# %run deconv.py \
    --sc_file "/mnt/d/ST_Graduation_Project/database/Wu/CID44971/CID44971_SC.h5ad" \
    --st_file "/mnt/d/ST_Graduation_Project/database/Wu/CID44971/CID44971_ST.h5ad" \
    --output_dir ./deconv_results \
    --stage1_n_epochs 500 \
    --stage2_gat_hidden_dim 512 \
    --stage2_n_epochs 500
